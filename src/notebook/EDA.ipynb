# %%
import pandas as pd
# Out:
# The kernel failed to start as the Python Environment 'venv (Python 3.8.0)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
